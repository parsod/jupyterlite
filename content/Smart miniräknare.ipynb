# %% [markdown]
# # Smart miniräknare

# %% [markdown]
# Den första rutan importerar bibliotek och definierar användbara konstanter, enhetsomvandlingar m.m. Tryck på Run notebook när du startar, så att allting körs. Titta på exempel-notebooken för att se hur du använder funktioner som plottning, linjär regression, ekvationslösning, integrering m.m.

# %%
from math import *
from numpy import *
import matplotlib.pyplot as plt
import scipy
import scipy.optimize
from scipy.optimize import fsolve
from scipy.integrate import quad, solve_ivp

#Fysikaliska konstanter, enhetsomvandlingar m.m. Allt i SI-enheter
atm=1.01325E5   #1 atm i pascal
torr=atm/760.0  #1 torr i pascal
R=8.3145   #Gaskonstanten
g=9.807    #jordaccelerationen
NA=6.022e23   #Avogadros tal
kB=R/NA    #Boltzmanns konstant
def tok(x): return x+273.15     #Funktion som omvandlar från grader till Kelvin
cal=4.184    #1 cal i joule    
kcal=1000*cal  #1 kcal i joule 
e0=1.6021765e-19  #Elementarladdningen
F=NA*e0    #Faradays konstant
eps0=8.854188e-12  #Vakuumpermittiviteten
h=6.62607e-34  #Plancks konstant
epsw=78.54    #Dielektricitetskonstanten för vatten vid 25 grader
D=3.33e-30  #Debye in Cm

# %% [markdown]
# ## Här nedanför skriver du själva uträkningarna.

# %% [markdown]
# Du kan antingen sudda ut varje gång eller skapa en ny ruta för varje uppgift (<> Code). Tryck på Run (en play-liknande knapp i rutans övre högra hörn) för att utföra beräkningarna i en ruta.

# %%
# Exempel: Beräkna volymen av 2.0 mol ideal gas vid 
# trycket 0.63 atm och temperaturen 25 grader celcius.

# Tips: Låt alla variabler ha SI-enheter
p=0.63*atm
T=tok(25)
n=2
V=n*R*T/p
print(V*1000, 'liter')
# Out:
# 77.66829743987405 liter

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=0b38ac8b-bbe1-4dd7-b428-f8cdffa219b0' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
